# %%
#1.a)
reset()
t=var('t')
x=function('x')(t)
u=var('s')
f=function('f')(s)
f(s)=s^2-2*s
eqp=solve(f(s)==0,s)

#stability theorem
x1=eqp[0].rhs()
x2=eqp[1].rhs()
#2 0

diff(f,u)(x1)
diff(f,u)(x2)

#graphical method
sf=plot_slope_field(f(s),(t,-5,5),(s,-3,3),headaxislength=3, headlength=4,color='red')
deq=diff(x,t)==f(x)
g1=desolve_rk4(deq, x, [0,-1], step=0.1, end_points= [-5,5], output='plot')
g2=desolve_rk4(deq, x, [0,0], step=0.1, end_points= [-5,5], output='plot')
g3=desolve_rk4(deq, x, [0,1], step=0.1, end_points= [-5,5], output='plot')
g4=desolve_rk4(deq, x, [0,2], step=0.1, end_points= [-5,5], output='plot')
g5=desolve_rk4(deq, x, [0,3], step=0.1, end_points= [-5,5], output='plot')

g=sf+g1+g2+g3+g4+g5
g.show(ymin=-3,ymax=3)
# Out:
# Graphics object consisting of 6 graphics primitives

# %%
#1.b)
reset()
t=var('t')
x=function('x')(t)
u=var('s')
f=function('f')(s)
f(s)=s*(s-1)*(s-2)
eqp=solve(f(s)==0,s)

#stability theorem
x1=eqp[0].rhs()
x2=eqp[1].rhs()
#0 1

diff(f,u)(x1)
diff(f,u)(x2)
#graphical method
sf=plot_slope_field(f(s),(t,-5,5),(s,-3,3),headaxislength=3, headlength=4,color='red')
deq=diff(x,t)==f(x)
g1=desolve_rk4(deq, x, [0,-0.5], step=0.1, end_points= [-5,5], output='plot')
g2=desolve_rk4(deq, x, [0,0], step=0.1, end_points= [-5,5], output='plot')
g3=desolve_rk4(deq, x, [0,0.5], step=0.1, end_points= [-5,5], output='plot')
g4=desolve_rk4(deq, x, [0,1], step=0.1, end_points= [-5,5], output='plot')
g5=desolve_rk4(deq, x, [0,1.5], step=0.1, end_points= [-5,5], output='plot')

g=sf+g1+g2+g3+g4+g5
g.show(ymin=-3,ymax=3)
# Out:
# Graphics object consisting of 6 graphics primitives

# %%
#2.a)
reset()
A=matrix([[2,1],[1,2]])
A.eigenvalues()
#3 1
x,y,t=var('x,y,t')
f1(x,y)=2*x+y
f2(x,y)=x+2*y

n=sqrt(f1(x,y)^2+f2(x,y)^2)
g=plot_vector_field( [f1(x,y)/n,f2(x,y)/n], [x,-5,5], [y,-5,5],color='red' ,aspect_ratio = 1)
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,2], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,2,1], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')

g.show(xmin=-5,xmax=5,ymin=-5,ymax=5)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
#2.b)
reset()
A=matrix([[1,1],[4,1]])
A.eigenvalues()
#3 -1
x,y,t=var('x,y,t')
f1(x,y)=x+4*y
f2(x,y)=x+y


n=sqrt(f1(x,y)^2+f2(x,y)^2)
g=plot_vector_field( [f1(x,y)/n,f2(x,y)/n], [x,-5,5], [y,-5,5],color='red' ,aspect_ratio = 1)
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,1], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,4,1], ivar = t, end_points = [-5,5], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')

g.show(xmin=-5,xmax=5,ymin=-5,ymax=5)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
#3.a)
x,y,t=var('x,y,t')
f1(x,y)=y
f2(x,y)=x*(1-x^2)+y
EquilP=solve([f1(x,y)==0,f2(x,y)==0],x,y)
#[x == -1, y == 0], [x == 1, y == 0], [x == 0, y == 0]
J=jacobian((f1(x,y),f2(x,y)), (x,y))
J(x=-1,y=0).eigenvalues()
#[-1/2*I*sqrt(7) + 1/2, 1/2*I*sqrt(7) + 1/2]
J(x=1,y=0).eigenvalues()
#[-1/2*I*sqrt(7) + 1/2, 1/2*I*sqrt(7) + 1/2]

n=sqrt(f1(x,y)^2+f2(x,y)^2)
g=plot_vector_field( [f1(x,y)/n,f2(x,y)/n], [x,-3,3], [y,-3,3],color='red' ,aspect_ratio = 1)
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,-1,0], ivar = t, end_points = [-10,10], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')

P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,0], ivar = t, end_points = [-10,10], step = 0.01)
XY=[ [j, k] for i,j,k in P]
g=g+list_plot(XY,plotjoined=True, color='blue')
g.show(xmin=-3,xmax=3,ymin=-3,ymax=3)
# Out:
# Graphics object consisting of 3 graphics primitives
